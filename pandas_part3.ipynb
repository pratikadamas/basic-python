# %% [markdown]
# # Reading, writing CSV and Excel file <br>

# %%
import pandas as pd

# %%
#Reading CSV file
d=pd.read_csv('datasets/weather.csv')
d.head(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Reading CSV file
# ----> 2 d=pd.read_csv('datasets/weather.csv')
#       3 d.head(3)
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/weather.csv'

# %%
#Reading excel file
df=pd.read_excel('datasets/titanic.xls')
df.head(3)

# %% [markdown]
# ### If you want to read only few rows rather than all

# %%
df=pd.read_csv('datasets/weather.csv',nrows=7)
df

# %% [markdown]
# ### Changing specific values with NaN while reading
#  * While reading the dataset you can change the specific value with NaN
#    > df = pd.read_excel ( " titanic.xls " , na_values = [ list of element which you want to change to NaN ] )

# %%
df = pd.read_excel("datasets/titanic.xls",na_values=[None]) 
df.head()

# %% [markdown]
# ### Changing specific values with NaN columns wise while reading

# %%
df=pd.read_excel('datasets/titanic.xls')
df.head()

# %%
df=pd.read_excel('datasets/titanic.xls',na_values={'body':[None],'boat':[None],'parch':[2,0]})

# %% [markdown]
#  * <b>na_values </b>argument is used to replace all the values passes in the list with NaN.You can also replace some invalid values column wise as you can in the above code. If you run the above code you will a dataframe where 'None' in body column is replaced by NaN,again None in the boat column is replaced by NaN and 2 & 0 in parch column are replaced by NaN.

# %% [markdown]
# ### Writing into CSV or excel
#  * You can convert any dataframe in a new CSV or excel file file

# %%
#Creatiing my own disctionary
mydict={
         'dates':['02-01-12','03-01-12','04-01-12','05-01-12','06-01-12'],
         'day':['sunny','rainy','hot','sunny','hot'],
         'wind-speed':[12,34,45,56,67],
         'temp':[45,46,47,48,49]
       }
#Converting disction to dataframe object
df=pd.DataFrame(mydict)

#Printing the dataframe
df
# Out:
#       dates    day  wind-speed  temp
# 0  02-01-12  sunny          12    45
# 1  03-01-12  rainy          34    46
# 2  04-01-12    hot          45    47
# 3  05-01-12  sunny          56    48
# 4  06-01-12    hot          67    49

# %% [markdown]
# ### Creating a new file

# %% [markdown]
# #### Creating a new csv file mycsv.csv

# %% [markdown]
# Suppose you have read a csv or excel file as dataframe object and you did some modification.Now you want to write a new csv or excel file that contains the modified dataframe. In that case you will need to_csv() or to_excel() function to create a new file.See the example below -

# %%
df.to_csv('datasets/mycsv.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.to_csv('datasets/mycsv.csv',index=False)
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'datasets'

# %% [markdown]
# #### Creating a new excel file myexcel.xls

# %%
df.to_excel('datasets/myexcel.xls',index=False)

# %% [markdown]
# ### Writing into csv or excel only selected rows
# <br>
# Suppose you modified the dataframe and you want to write it in another csv file with only selected columns.In the following example we have created the new csv file mycsv_few_columns.csv by "df" dataframe allowing only three columns which we want i.e, day, temp, wind-speed and i have ignored the date column.

# %% [markdown]
# #### how many columns in dataframe df ?

# %%
df.columns

# %%
#Writing only three columns day,temp,wind-speed
df.to_csv('datasets/mycsv_few_columns.csv',columns=['day','temp','wind-speed'],index=False)

#Again reading to see the result
d=pd.read_csv('datasets/mycsv_few_columns.csv')
d
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 2
#       1 #Writing only three columns day,temp,wind-speed
# ----> 2 df.to_csv('datasets/mycsv_few_columns.csv',columns=['day','temp','wind-speed'],index=False)
#       4 #Again reading to see the result
#       5 d=pd.read_csv('datasets/mycsv_few_columns.csv')
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'datasets'

# %% [markdown]
# ### Converters :

# %% [markdown]
# In various cases you dont have clean dataset. Invalid values in the dataset leads to a lot of problem while predicting or extracting the meaningful information.To avoid this problem we use converters.
# * Converters are basically functions which convert the specific value of a column in your desire value
# * Converter function passed into the disctionary like in the na_values.

# %% [markdown]
# This is our dataset in which you can see that there are lots of invalid values are present.These values are noise in our dataset.

# %%
import pandas as pd
import  numpy as np

# %%
df=pd.read_csv(r'E:\basic python\season.csv')
df
# Out:
#        dates    day  temp     wind-speed
# 0   2/1/2012  sunny  45.0             12
# 1   3/1/2012  rainy  46.0             34
# 2   4/1/2012    hot  47.0             45
# 3   5/1/2012    NaN   NaN             56
# 4   6/1/2012    hot  49.0  Not available
# 5   7/1/2012    NaN   NaN  Not available
# 6   8/1/2012    hot  12.0             45
# 7   9/1/2012  rainy  23.0             41
# 8  10/1/2012    NaN   NaN            NaN
# 9  11/1/2012    NaN   NaN            NaN

# %%
xx=np.mean(df['temp'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 xx=np.mean(df['temp'])
#
# NameError: name 'np' is not defined

# %%
df["temp"].fillna(np.mean(df['temp']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df["temp"].fillna(np.mean(df['temp']))
#
# NameError: name 'np' is not defined

# %%
df.drop("temp",axis=1)
# Out:
#        dates    day     wind-speed
# 0   2/1/2012  sunny             12
# 1   3/1/2012  rainy             34
# 2   4/1/2012    hot             45
# 3   5/1/2012    NaN             56
# 4   6/1/2012    hot  Not available
# 5   7/1/2012    NaN  Not available
# 6   8/1/2012    hot             45
# 7   9/1/2012  rainy             41
# 8  10/1/2012    NaN            NaN
# 9  11/1/2012    NaN            NaN

# %%
pd.concat(df,v1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pd.concat(df,v1)
#
# NameError: name 'v1' is not defined

# %%
df
# Out:
#        dates    day  temp     wind-speed
# 0   2/1/2012  sunny  45.0             12
# 1   3/1/2012  rainy  46.0             34
# 2   4/1/2012    hot  47.0             45
# 3   5/1/2012    NaN   NaN             56
# 4   6/1/2012    hot  49.0  Not available
# 5   7/1/2012    NaN   NaN  Not available
# 6   8/1/2012    hot  12.0             45
# 7   9/1/2012  rainy  23.0             41
# 8  10/1/2012    NaN   NaN            NaN
# 9  11/1/2012    NaN   NaN            NaN

# %% [markdown]
# #### The following function will convert any cell of column having 'NaN' into 40, so here we will apply this function into 'temp' column and so for the 'day' and 'wind-speed' columns.

# %%
def converter_for_temp(col):
    if col=='NaN':
        return 40
    else:
        return col
def converter_for_day(col):
    if col=='NaN':
        return 'sunny'
    else:
        return col
def converter_for_wind_speed(col):
    if col=='Not available':
        return 30
    elif col=="NaN":
        return 48
    else:
        return col

# %%
df=pd.read_csv('datasets/season.csv',converters={
    'day':converter_for_day,
    'temp':converter_for_temp,
    'wind-speed':converter_for_wind_speed
   })
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df=pd.read_csv('datasets/season.csv',converters={
#       2     'day':converter_for_day,
#       3     'temp':converter_for_temp,
#       4     'wind-speed':converter_for_wind_speed
#       5    })
#       6 df
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/season.csv'

# %% [markdown]
# You can observe that previously the columns 'day', 'temp' and 'wind-speed' had some invalid data like 'NaN','NAN','Not available' but after applying the converter functions we got a cleaned dataset.Now we can apply some data analysis techniquw to predict something in our dataset.

# %% [markdown]
# ### Writing different dataframes into one file but different sheet names

# %% [markdown]
# Let's assume that you have two different dataframes and you want to write it in the same excel sheet but different sheet names.
# <br>
#
# Let's take two disctionary one is "weather1" and another is "house1" and make it two dataframe "weather" & "house"

# %%
#Creating weather disctionary
weather1={
         'dates':['02-01-12','03-01-12','04-01-12','05-01-12','06-01-12'],
         'day':['sunny','rainy','hot','sunny','hot'],
         'wind-speed':[12,34,45,56,67],
         'temp':[45,46,47,48,49]
       }
#Converting disction to dataframe object
weather=pd.DataFrame(weather1)

#Creating house disctionary
house1={
         'dates':['02-01-12','03-01-12','04-01-12','05-01-12','06-01-12'],
         'price':[20000,30000,40000,50000,60000],
         'bhk':[1,3,2,1,2],
         'how-old':[2,5,2,7,4]
       }

#converting house disctionary to dataframe object

house=pd.DataFrame(house1)

# %% [markdown]
#  Call the "ExcelWriter" and make a object "writer".Now call to_excel() function and pass three argument -
#   * <b>1. "writer" object :</b>
#   * <b>2. sheet_name : </b>
#   * <b>3. Index :</b> This is optional for you

# %%
with pd.ExcelWriter('datasets/weather_and_house.xls') as writer:
   weather.to_excel(writer,sheet_name='Weather',index=False)
   house.to_excel(writer,sheet_name='House',index=False)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\excel\_base.py:1136, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1135 try:
# -> 1136     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1137     if engine == "auto":
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\_config\config.py:274, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     273 def __call__(self, *args, **kwds) -> T:
# --> 274     return self.__func__(*args, **kwds)
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\_config\config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     148     # walk the nested dict
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\_config\config.py:132, in _get_single_key(pat, silent)
#     131         _warn_if_deprecated(pat)
# --> 132     raise OptionError(f"No such keys(s): {repr(pat)}")
#     133 if len(keys) > 1:
#
# OptionError: No such keys(s): 'io.excel.xls.writer'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 with pd.ExcelWriter('datasets/weather_and_house.xls') as writer:
#       2    weather.to_excel(writer,sheet_name='Weather',index=False)
#       3    house.to_excel(writer,sheet_name='House',index=False)
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\excel\_base.py:1140, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1138             engine = get_default_engine(ext, mode="writer")
#    1139     except KeyError as err:
# -> 1140         raise ValueError(f"No engine for filetype: '{ext}'") from err
#    1142 # for mypy
#    1143 assert engine is not None
#
# ValueError: No engine for filetype: 'xls'

# %% [markdown]
# #### Now access the sheets separately by passing its name while reading
# See the example

# %%
d1=pd.read_excel('datasets/weather_and_house.xls','Weather')
d1

# %%
d2=pd.read_excel('datasets/weather_and_house.xls','House')
d2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 d2=pd.read_excel('datasets/weather_and_house.xls','House')
#       2 d2
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~\OneDrive\Desktop\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/weather_and_house.xls'

# %%
#Creatiing my own disctionary
mydict={
         'dates':['02-01-12','03-01-12','04-01-12','05-01-12','06-01-12'],
         'day':['sunny','rainy','hot','sunny','hot'],
         'wind-speed':[12,34,45,56,67],
         'temp':[45,46,47,48,49]
       }
#Converting disction to dataframe object
df=pd.DataFrame(mydict)

#Printing the dataframe
df
# Out:
#       dates    day  wind-speed  temp
# 0  02-01-12  sunny          12    45
# 1  03-01-12  rainy          34    46
# 2  04-01-12    hot          45    47
# 3  05-01-12  sunny          56    48
# 4  06-01-12    hot          67    49

# %%
df.head(2)
# Out:
#       dates    day  wind-speed  temp
# 0  02-01-12  sunny          12    45
# 1  03-01-12  rainy          34    46

# %%
df.tail(2)
# Out:
#       dates    day  wind-speed  temp
# 3  05-01-12  sunny          56    48
# 4  06-01-12    hot          67    49

# %%
df.iloc[0:,0]
# Out:
# 0    02-01-12
# 1    03-01-12
# 2    04-01-12
# 3    05-01-12
# 4    06-01-12
# Name: dates, dtype: object

# %%
df["day"]
# Out:
# 0    sunny
# 1    rainy
# 2      hot
# 3    sunny
# 4      hot
# Name: day, dtype: object

# %%
df.drop("day" ,axis=1)
# Out:
#       dates  wind-speed  temp
# 0  02-01-12          12    45
# 1  03-01-12          34    46
# 2  04-01-12          45    47
# 3  05-01-12          56    48
# 4  06-01-12          67    49

# %%
df
# Out:
#       dates    day  wind-speed  temp
# 0  02-01-12  sunny          12    45
# 1  03-01-12  rainy          34    46
# 2  04-01-12    hot          45    47
# 3  05-01-12  sunny          56    48
# 4  06-01-12    hot          67    49

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dates       5 non-null      object
#  1   day         5 non-null      object
#  2   wind-speed  5 non-null      int64
#  3   temp        5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %%
df.describe()
# Out:
#        wind-speed       temp
# count    5.000000   5.000000
# mean    42.800000  47.000000
# std     21.158922   1.581139
# min     12.000000  45.000000
# 25%     34.000000  46.000000
# 50%     45.000000  47.000000
# 75%     56.000000  48.000000
# max     67.000000  49.000000

# %%
df['wind-speed']
# Out:
# 0    12
# 1    34
# 2    45
# 3    56
# 4    67
# Name: wind-speed, dtype: int64

# %%
df['wind-speed']=df['wind-speed']+20

# %%
df['wind-speed']
# Out:
# 0    32
# 1    54
# 2    65
# 3    76
# 4    87
# Name: wind-speed, dtype: int64

# %%
df['wind-speed'].unique()
# Out:
# array([32, 54, 65, 76, 87])

# %%
df['day'].value_counts()
# Out:
# day
# sunny    2
# hot      2
# rainy    1
# Name: count, dtype: int64

# %%
# create a new column
df["humidity"]=df['temp']+30

# %%
df
# Out:
#       dates    day  wind-speed  temp  humidity
# 0  02-01-12  sunny          32    45        75
# 1  03-01-12  rainy          54    46        76
# 2  04-01-12    hot          65    47        77
# 3  05-01-12  sunny          76    48        78
# 4  06-01-12    hot          87    49        79

# %%
df.isnull().sum()
# Out:
# dates         0
# day           0
# wind-speed    0
# temp          0
# humidity      0
# dtype: int64

# %%
a=df[df['day'].duplicated()]
a
# Out:
#       dates    day  wind-speed  temp  humidity
# 3  05-01-12  sunny          76    48        78
# 4  06-01-12    hot          87    49        79

# %%
df[["day",'month','year']]=df['dates'].str.split('-',expand=True)
b=df[['day', 'month', 'year']]

# %%
import numpy as np
df
# Out:
#       dates day  wind-speed  temp  humidity month year
# 0  02-01-12  02          32    45        75    01   12
# 1  03-01-12  03          54    46        76    01   12
# 2  04-01-12  04          65    47        77    01   12
# 3  05-01-12  05          76    48        78    01   12
# 4  06-01-12  06          87    49        79    01   12

# %%
#Creatiing my own disctionary
mydict={
         'dates':['02-01-12','03-01-12','04-01-12','05-01-12','06-01-12'],
         'day':['sunny','rainy','hot','sunny','hot'],
         'wind-speed':[12,34,45,56,67],
         'temp':[45,46,47,48,49]
       }
#Converting disction to dataframe object
df=pd.DataFrame(mydict)

#Printing the dataframe
df
# Out:
#       dates    day  wind-speed  temp
# 0  02-01-12  sunny          12    45
# 1  03-01-12  rainy          34    46
# 2  04-01-12    hot          45    47
# 3  05-01-12  sunny          56    48
# 4  06-01-12    hot          67    49

# %%
b=df['dates'].str.split('-',expand=True)

# %%
b
# Out:
#     0   1   2
# 0  02  01  12
# 1  03  01  12
# 2  04  01  12
# 3  05  01  12
# 4  06  01  12

# %%
df["day-no"]=b[0]
df['month']=b[1]
df['year']=b[2]

# %%
df
# Out:
#       dates    day  wind-speed  temp day-no month year
# 0  02-01-12  sunny          12    45     02    01   12
# 1  03-01-12  rainy          34    46     03    01   12
# 2  04-01-12    hot          45    47     04    01   12
# 3  05-01-12  sunny          56    48     05    01   12
# 4  06-01-12    hot          67    49     06    01   12

# %%
p=df['day'].duplicated()
p
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# Name: day, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       dates    day  wind-speed  temp day-no month year
# 0  02-01-12  sunny          12    45     02    01   12
# 1  03-01-12  rainy          34    46     03    01   12
# 2  04-01-12    hot          45    47     04    01   12
# 3  05-01-12  sunny          56    48     05    01   12
# 4  06-01-12    hot          67    49     06    01   12

# %%
df.info
# Out:
# <bound method DataFrame.info of       dates    day  wind-speed  temp day-no month year
# 0  02-01-12  sunny          12    45     02    01   12
# 1  03-01-12  rainy          34    46     03    01   12
# 2  04-01-12    hot          45    47     04    01   12
# 3  05-01-12  sunny          56    48     05    01   12
# 4  06-01-12    hot          67    49     06    01   12>

# %%
df.iloc[:,1:].corr
# Out:
# <bound method DataFrame.corr of      day  wind-speed  temp day-no month year
# 0  sunny          12    45     02    01   12
# 1  rainy          34    46     03    01   12
# 2    hot          45    47     04    01   12
# 3  sunny          56    48     05    01   12
# 4    hot          67    49     06    01   12>

# %%
stu={'id':[123,124,125,126,127],
     'name':['Alice','Bob','Carol','joy','josh'],
     'age':[21,22,23,24,20]
     }
stu=pd.DataFrame(stu)
stu
# Out:
#     id   name  age
# 0  123  Alice   21
# 1  124    Bob   22
# 2  125  Carol   23
# 3  126    joy   24
# 4  127   josh   20

# %%
cor={"id":[123,124,125,128],
     "Sname":['coa','dsa','toc','digital']}
cor=pd.DataFrame(cor)
cor
# Out:
#     id    Sname
# 0  123      coa
# 1  124      dsa
# 2  125      toc
# 3  128  digital

# %%
stu.merge(cor ,how='inner',on='id')
# Out:
#     id   name  age Sname
# 0  123  Alice   21   coa
# 1  124    Bob   22   dsa
# 2  125  Carol   23   toc

# %%
stu.merge(cor ,how='outer',on='id')
# Out:
#     id   name   age    Sname
# 0  123  Alice  21.0      coa
# 1  124    Bob  22.0      dsa
# 2  125  Carol  23.0      toc
# 3  126    joy  24.0      NaN
# 4  127   josh  20.0      NaN
# 5  128    NaN   NaN  digital

# %%
stu.merge(cor ,how='left',on='id')
# Out:
#     id   name  age Sname
# 0  123  Alice   21   coa
# 1  124    Bob   22   dsa
# 2  125  Carol   23   toc
# 3  126    joy   24   NaN
# 4  127   josh   20   NaN

# %%
stu.merge(cor ,how='right',on='id')
# Out:
#     id   name   age    Sname
# 0  123  Alice  21.0      coa
# 1  124    Bob  22.0      dsa
# 2  125  Carol  23.0      toc
# 3  128    NaN   NaN  digital

# %%
stu.merge(cor ,how='cross')
# Out:
#     id_x   name  age  id_y    Sname
# 0    123  Alice   21   123      coa
# 1    123  Alice   21   124      dsa
# 2    123  Alice   21   125      toc
# 3    123  Alice   21   128  digital
# 4    124    Bob   22   123      coa
# 5    124    Bob   22   124      dsa
# 6    124    Bob   22   125      toc
# 7    124    Bob   22   128  digital
# 8    125  Carol   23   123      coa
# 9    125  Carol   23   124      dsa
# 10   125  Carol   23   125      toc
# 11   125  Carol   23   128  digital
# 12   126    joy   24   123      coa
# 13   126    joy   24   124      dsa
# 14   126    joy   24   125      toc
# 15   126    joy   24   128  digital
# 16   127   josh   20   123      coa
# 17   127   josh   20   124      dsa
# 18   127   josh   20   125      toc
# 19   127   josh   20   128  digital

# %%
import numpy as np

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

c = np.cross(a, b)
print(c)
# Out:
# [-3  6 -3]
